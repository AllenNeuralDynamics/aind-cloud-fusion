# %%
import numpy as np
import matplotlib.pyplot as plt
import zarr

# %%
output_path = "tmp/fused_in_x.zarr/0"
arr = zarr.open(output_path, mode="r")
fused_data = arr[0, 0, :, :, :]

fused_data.shape
# Out:
# (200, 400, 200)

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
from tests.test_dataset import generate_masked_x_dataset
gt, dataset = generate_masked_x_dataset()
plt.imshow(gt[:, 0, :] - fused_data[:, 0, :])

import numpy as np
np.sum(gt[:, 0, :] - fused_data[:, 0, :])
# Out:
# 0.0

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# %%
# %matplotlib inline
plt.imshow(fused_data[:, 0, :])
plt.show()

# Conditional logic with masking is working, however,
# when chunk to color is wider than the masked area, 
# we fill the non-overlapping area with no signal.

# %%
from tests.test_dataset import generate_masked_x_dataset
gt, dataset = generate_masked_x_dataset()

# %%
plt.imshow(gt[:, 0, :])
plt.show()
gt.shape
# Out:
# (200, 400, 200)

# %%
tile_1 = dataset.tile_volumes_zyx[0][:, 0, :]
plt.imshow(tile_1)
tile_1.shape
# Out:
# (200, 150)

# %%
tile_2 = dataset.tile_volumes_zyx[1][:, 0, :]
plt.imshow(tile_2)
tile_2.shape
# Out:
# (200, 150)
